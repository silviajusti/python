# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv("master.csv")

# %%
data.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
set(data['age'])
# Out:
# {'15-24 years',
#  '25-34 years',
#  '35-54 years',
#  '5-14 years',
#  '55-74 years',
#  '75+ years'}

# %%
x=set(data['age'])

# %%
# ?plt.bar

# %% [markdown]
# Is the suicide rate more prominent in some age categories than others?

# %%
plt.bar(data['age'],data['suicides_no'])
plt.show()

# %% [markdown]
# yes. between 35 and 54 y of age

# %% [markdown]
# Which countries have the most and the least number of suicides?

# %%
plt.bar(data['country'],data['suicides_no'])
plt.show()

# %%
data.loc[data['suicides_no'] == min(data['suicides_no'])]
# Out:
#        country  year     sex          age  suicides_no  population  \
# 9      Albania  1987  female   5-14 years            0      311000
# 10     Albania  1987  female  55-74 years            0      144600
# 11     Albania  1987    male   5-14 years            0      338200
# 22     Albania  1988  female   5-14 years            0      317200
# 23     Albania  1988    male   5-14 years            0      345000
# ...        ...   ...     ...          ...          ...         ...
# 27363  Uruguay  1998  female   5-14 years            0      262973
# 27459  Uruguay  2006  female   5-14 years            0      260187
# 27471  Uruguay  2007  female   5-14 years            0      257931
# 27495  Uruguay  2009    male   5-14 years            0      263516
# 27543  Uruguay  2014  female   5-14 years            0      243247
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 9                    0.0  Albania1987           NaN      2,156,624,900
# ...

# %%
data2 = data.groupby(["country"]).suicides_no.sum().reset_index()
print(data2)
# Out:
#                   country  suicides_no
# 0                 Albania         1970
# 1     Antigua and Barbuda           11
# 2               Argentina        82219
# 3                 Armenia         1905
# 4                   Aruba          101
# ..                    ...          ...
# 96   United Arab Emirates          622
# 97         United Kingdom       136805
# 98          United States      1034013
# 99                Uruguay        13138
# 100            Uzbekistan        34803
#
# [101 rows x 2 columns]
# 'suicides_no'

# %%
data2.loc[data2['suicides_no'] == min(data2['suicides_no'])]
# Out:
#                   country  suicides_no
# 27               Dominica            0
# 76  Saint Kitts and Nevis            0

# %%
data2.loc[data2['suicides_no'] == max(data2['suicides_no'])]
# Out:
#                country  suicides_no
# 75  Russian Federation      1209742

# %% [markdown]
# Least: Dominica and St. Kitts and Nevis
# Most:
# Russia

# %%
# plot the scatter plot for the variables 'total_bill' and 'tip'

X = data['population']
Y = data['suicides_no']

# plot the scatter plot
# s is for shape, c is for colour, alpha is for opacity (0 < alpha < 1)
plt.scatter(X, Y)

# add title 
plt.title('Scatter Plot')

# add the axes labels to the plot
plt.xlabel('population')
plt.ylabel('suicides_no')

# display the plot
plt.show()

# %%
X = data['population']
Y = data['suicides/100k pop']

# plot the scatter plot
# s is for shape, c is for colour, alpha is for opacity (0 < alpha < 1)
plt.scatter(X, Y)

# add title 
plt.title('Scatter Plot')

# add the axes labels to the plot
plt.xlabel('population')
plt.ylabel('suicides/100k')

# display the plot
plt.show()

# %%
figure = plt.figure(figsize=(20,10))
ax =sns.scatterplot(x='population', y='suicides_no', data=data, size='suicides_no')

# %%
figure = plt.figure(figsize=(20,10))
ax =sns.regplot(x='population', y='suicides_no', data=data)

# %%
figure = plt.figure(figsize=(20,10))
ax =sns.lineplot(x='population', y='suicides_no', data=data)

# %% [markdown]
# What is the effect of the GDP of a country on suicide rates?

# %%
# plot the scatter plot for the variables 'total_bill' and 'tip'

X = data['population']
Y = data['gdp_per_capita ($)']

# plot the scatter plot
# s is for shape, c is for colour, alpha is for opacity (0 < alpha < 1)
plt.scatter(X, Y)

# add title 
plt.title('Scatter Plot')

# add the axes labels to the plot
plt.xlabel('population')
plt.ylabel('gdp_per_capita ($)')

# display the plot
plt.show()

# %%
figure = plt.figure(figsize=(20,10))
sns.regplot(x='gdp_per_capita ($)', y='suicides/100k pop', data=data)
# Out:
# <AxesSubplot:xlabel='gdp_per_capita ($)', ylabel='suicides/100k pop'>

# %%
data.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
figure = plt.figure(figsize=(20,10))
corr_matrix=data.corr()

sns.heatmap(corr_matrix, annot = True)

# display the plot
plt.show()

# %% [markdown]
# What is the effect of the population on suicide rates? == positive correlation (0.62)

# %% [markdown]
# What is the trend of suicide rates across all the years? == looks stable

# %%
# plot the scatter plot for the variables 'total_bill' and 'tip'

X = data['year']
Y = data['suicides/100k pop']

# plot the scatter plot
# s is for shape, c is for colour, alpha is for opacity (0 < alpha < 1)
plt.scatter(X, Y)

# add title 
plt.title('Scatter Plot')

# add the axes labels to the plot
plt.xlabel('year')
plt.ylabel('suicides/100k pop')

# display the plot
plt.show()

# %%
# plot the scatter plot for the variables 'total_bill' and 'tip'

X = data['year']
Y = data['suicides_no']

# plot the scatter plot
# s is for shape, c is for colour, alpha is for opacity (0 < alpha < 1)
plt.scatter(X, Y)

# add title 
plt.title('Scatter Plot')

# add the axes labels to the plot
plt.xlabel('year')
plt.ylabel('suicides/100k pop')

# display the plot
plt.show()

# %%
data[['year','suicides_no' ]].groupby(['year']).sum().plot(figsize=(15,5))
plt.show()

# %% [markdown]
# Is there a difference between the suicide rates of men and women?
# Oh yes!

# %%
plt.bar(data['sex'],data['suicides_no'])
plt.show()

# %%
figure = plt.figure(figsize=(15,5))
sns.barplot(data=data, x='sex', y= 'suicides_no', hue = 'age')
plt.show()
